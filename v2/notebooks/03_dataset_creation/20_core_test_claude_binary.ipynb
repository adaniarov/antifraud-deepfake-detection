# %% [markdown]
# # 20 — Derived slice `test_claude_binary`
#
# Строит `core_test_claude_binary.jsonl`: Claude holdout (label=1) + согласованные human companions из **резерва** dataset1 (не из train/val/test_seen).
#
# Запуск обновляет `core_manifest.json`, crosstab CSV, блок в `core_split_diagnostics.md` (между HTML-маркерами).
#
# **Модуль:** `v2/src/core_test_claude_binary.py`.

# %%
from pathlib import Path
import sys
BASE = Path.cwd().resolve()
for p in [BASE, *BASE.parents]:
    if (p / "v2" / "pyproject.toml").is_file():
        sys.path.insert(0, str(p / "v2"))
        break
else:
    sys.path.insert(0, str(BASE))
from src.core_test_claude_binary import main
main()
